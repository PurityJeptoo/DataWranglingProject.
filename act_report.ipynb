# %% [markdown]
# # Analysis and Visualization Report
#
# <p> After cleaning my data and merging all the three datasets to one, I perfomed an analysis on it so as to understand it better.</p>
#
# <p> My first analysis was on Dog_stage.I wanted to check the distribution of dogstages that is how many dogs are in a certain stage and even determine the Dog_stage with the highest or lowest number of dogs. I used the value_counts command to see the count of each dog_stage and also used histogram so as to visualize the dogstage. From the command and histogram, I saw that pupper was the dogstage with the highest count that is 207 while doggo,puppo had the lowest count with 1. I was curious to know,how dogs in pupper stage look like, thus I wrote a code to retrieve their images.</p>

# %% [markdown]
# #### The histogram below is a visualization of the dog_stage
#
# ![Capture_1.PNG](attachment:Capture_1.PNG)

# %% [markdown]
# <p> I also checked on which tweets and images had the highest favorite count. Firstly, i sorted the favorite count column in descending order, and then I created a dataframe with tweet_id,jpg_url,favorite_count and Dog_stage as columns. After calling using.head(),it outputs the first five tweet_ids and images with highest favorite count. tweet_id = 822872901745569793 had the highest favorite count. I was also able to check the image of this dog which was liked the most and also with the least likes.</p>

# %% [markdown]
# #### Image of the dog with the most likes.
# ![Capture_2.PNG](attachment:Capture_2.PNG)

# %% [markdown]
# #### Image of the dog with least likes.
# ![cap_6.PNG](attachment:cap_6.PNG)

# %% [markdown]
# <p> My third analysis was on predictions. I focused more on first prediction, where I wanted to know which prediction had the highest count. I plotted a bargraph so as to identify first prediction with the highest count. The output showed that Golden Retriever had the top count. I then queryied the Golden Retriever from p1 ,to see which tweet_ids corresponds to this prediction. I also checked on an image to see how a Golden Retriever breed looks like.</p>

# %% [markdown]
# #### The graph below shows the distribution of first prediction.
# ![Capture_3.PNG](attachment:Capture_3.PNG)
